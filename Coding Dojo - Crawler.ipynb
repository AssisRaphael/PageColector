# %% [markdown]
# # ☯ Coding Dojo ☯

# %% [markdown]
# <img style="float:left" src="imgs/vamos_coletar.png">
# ## Regras
#
# Ponto de participação, poderá perdido se:
#
#     - Aluno atrasado (ver política de atraso na especificação)
#     - Recusar participação como piloto/copiloto
#         - Ou não querer sair do computador, quando solicitado :-)
#     - Demorar para sair quando solicitado
#     - Parar de participar por:
#         - Uso de outro computador
#         - Uso de celular
#         - Usar a internet
#         - Conversa

# %% [markdown]
# Antes de entregar, certifique-se que tenha executado todos os comandos/códigos deste Jupyter. É obrigatório que todas as saídas tenham sido apresentadas. Perda de 3 pontos caso não tenham feito isso.

# %% [markdown]
# # Dependencias

# %% [markdown]
# Se necessário, instale o python3 e o pip3 abaixo usando `sudo apt-get install python3 python3-pip`.  Execute abaixo para instalar o [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/). Qualquer linha de comando/código como a de baixo, você pode executá-la a selecionando e pressionando `ctrl+enter` ❣️.

# %%
# !pip3 install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\rapha\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\rapha\anaconda3\lib\site-packages (from bs4) (4.6.0)

# %% [markdown]
# Caso de comando não encontrado `pip3` use `pip`.

# %% [markdown]
# # Coletor

# %% [markdown]
# <img src="imgs/arquitetura_coletor.png">

# %% [markdown]
# Você deverá completar a implementação das três classes abaixo para fazer o coletor: `Domain`, `Scheduler` e `PageFetcher`. Conforme figura acima, o `Scheduler` é responsável por armazenar as filas de URLs a serem requisitadas; o PageFetcher serão *threads* responsáveis por fazer as requisições das URLs obtidas por meio do escalonador (instancia da classe `Scheduler`). A classe `Domain` armazena informações importantes sobre o servidor a serem usadas no momento do escalonamento das URLs.

# %% [markdown]
# ## Classe `Domain`

# %% [markdown]
# <figure style="text-align:center">
#     <img src="imgs/estrutura_coletor.png">
#     <caption>Fonte: Baeza-Yates e Ribeiro-Neto, 2011 </caption>
# </figure>

# %% [markdown]
# Antes de começar a fazer o escalonador (classe `Scheduler`) devemos implementar a classe que representa os domínios. Conforme visto na figura acima, o escalonador possuirá diversas filas, uma para cada servidor.  Em nosso caso, o servidor será um domínio - que você irá implementar na classe `Domain` do arquivo `domain.py`.
#
# O escalonador percorrerá cada servidor e obterá o primeiro da fila do primeiro servidor acessível. O servidor é acessível obdecendo o limite de tempo entre requisições (em segundos, usando o atributo `int_time_limit_between_requests`).
#
# Nesta atividade você irá implementar a classe `Domain`, que já possui os seguintes atributos:
#
# - *int_time_limit_between_requests*: Limite entre requisições (int)
# - *nam_domain*: Nome do domínio (String)
# - *time_last_access*: [Objeto Datetime](https://docs.python.org/3/library/datetime.html#datetime-objects) informando da data/hora do último acesso
#
# O prefixo da variável sempre irá denotar o tipo da mesma.

# %% [markdown]
# **Atividade 1 - classe `Domain`**: Complete a classe `Domain` implementando os métodos/atributos calculados descritos a seguir. Logo após, execute o ❣️ teste unitário ❣️ para verificar se os métodos/atributos calculados foram implementados conforme esperado.
#
# - **accessed_now**: Método que modifica o último acesso com a data/hora atual usando um [objeto datetime](https://docs.python.org/3/library/datetime.html#datetime-objects)
# - **time_since_last_access**: Atributo calculado que retorna um [objeto TimeDelta](https://docs.python.org/3/library/datetime.html#timedelta-objects) com a diferença da data atual e a data do último acesso. Veja os exemplos de uso do TimeDelta na sua documentação
# - **is_accessible**: Método que verdadeiro se o domínio estiver acessível

# %% [markdown]
# Os métodos `count_fetched_page` e `has_finished_crawl` já estão implementados. Execute o teste unitário a seguir. Veja que o comando abaixo executa o teste unitário presente no arquivo `crawler/scheduler_test.py`. Analise-o para entender como implementamos testes unitários.

# %%
# !python -m crawler.scheduler_test DomainTest.test_domain
# Out:
# Verificando acesso a um dominio já requisitado (após espera)
# aguardando 10 segundos...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 10.012s
#
# OK

# %% [markdown]
# **Atividade 2 - métodos `__hash__` e `__eq__` da classe `Domain`**: A fila será implementada por um dicionario ordenado ([OrderedDict](https://docs.python.org/2/library/collections.html#collections.OrderedDict)) em que a chave será um objeto da classe domínio e o valor serão uma lista de URLs. Para que seja possível a busca do domínio, você deverá implementar os métodos `__hash__` e `__eq__` de forma similar ao seguinte exemplo:

# %%
from collections import OrderedDict
class Xuxu():
    def __str__(self):
        return "xuxuuu"
    
    def __hash__(self):
        return hash("xuxu")
    def __eq__(self, x):
        return x == "xuxu"
d = OrderedDict()
d[Xuxu()] = 'A'
print("xuxu" in d)
# Out:
# True

# %% [markdown]
# Em nosso caso, deve ser permitido fazer a busca no dicionario pelo nome do domínio ou pelo objeto, ou seja, após a implementação desta atividade, o seguinte código irá funcionar corretamente:

# %%
from crawler.domain import Domain
from collections import OrderedDict

obj_domain = Domain("oi.com",10)
dic_x = OrderedDict()
dic_x[obj_domain] = "lala"
dic_x["oi.com"] = "oi"

#abaixo, em ambos os casos, será encontrado/impresso a string "oi"
print(dic_x["oi.com"])
print(dic_x[obj_domain])
# Out:
# oi
# oi

# %% [markdown]
# Lembre-se que, em nosso caso, o parametro do método `__eq__` pode ser um objeto da classe `Domain` ou uma string representando o nome do domínio. Caso faça alguma modificação no código, você deverá reiniciar o kernel para que o efeito seja visto no código acima (para reiniciar, clique em Kernel->Restart). Isso ocorre que, uma vez dado import em um módulo, esse modulo não é alterado no Jupyter caso você faça uma modificação no código.

# %% [markdown]
# ## Classe `Scheduler`

# %% [markdown]
# Agora você irá implementar o escalonador. Essa classe será responsável por gerenciar as URLs.
# Para isso, será implementado as filas por servidores conforme apresentado na figura da seção anterior.
# Para isso, utilizaremos um OrderedDict em que as chaves são os servidores (objeto da classe `Domain`) e o valor será uma lista de tuplas com as URLs e sua profundidade. Com o objetivo de armazenar as URLs de forma estruturada, as mesmas **não serão** string, ao invés disso, serão objetos da classe `ParseResult` - essa classe é retornada do método [urlparse](https://docs.python.org/3/library/urllib.parse.html). Veja um exemplo abaixo.

# %%
from crawler.domain import Domain
from crawler.scheduler import Scheduler
from urllib.parse import urlparse

dict_filas_por_servidor = {Domain("www.globo.com",10):[
                                                (urlparse("http://www.globo.com/esporte"),1),
                                                (urlparse("http://www.globo.com/noticia_um"),2),
                                                (urlparse("http://www.globo.com/noticia_dois"),3),
                                                (urlparse("http://www.globo.com/noticia_tres"),3),
                                                ],
                            Domain("www.cnpq.br",10):[(urlparse("http://www.cnpq.br/pesquisadores"),1),
                                               (urlparse("http://www.cnpq.br/bolsas"),1)]
                          }

# %% [markdown]
# Assim, a classe `Scheduler`, no arquivo `scheduler.py` possui os seguintes atributos:
#
# - `str_usr_agent`: Nome do `User agent`. Usualmente, é o nome do navegador, em nosso caso,  será o nome do coletor (usualmente, terminado em `bot`)
# - `int_page_limit`: Número de páginas a serem coletadas
# - `int_depth_limit`: Profundidade máxima a ser coletada
# - `int_page_count`: Quantidade de página já coletada
# - `dic_url_per_domain`: Fila de URLs por domínio (explicado anteriormente)
# - `set_discovered_urls`: Conjunto de URLs descobertas, ou seja, que foi extraída em algum HTML e já adicionadas na fila - mesmo se já ela foi retirada da fila. A URL armazenada deve ser uma string.
# - `dic_robots_per_domain`: Dicionário armazenando, para cada domínio, o objeto representando as regras obtidas no `robots.txt`

# %% [markdown]
# **Atividad 3 - Método `can_add_page`**: Esse método irá retornar verdadeiro caso seja possível adicionar a página `obj_url` (objeto da classe ParseResult) que foi coletada na profundidade `int_depth`. Para que seja possível adicionar na lista, esta pagina não deve ter sido descoberta e nem com a profundidade maior que o limite. Este método será testado por teste unitário apenas após a implementação da adição e obtenção das URLs.

# %% [markdown]
# **Atividade 4 método `add_new_page` - Adicionar nova página**:  Este método retorna falso caso não seja possível adicionar a página (por meio do método `can_add_page`) e verdadeiro, caso contrário. Caso seja possível, deve-se adicionar a url `obj_url` na fila `dic_url_per_domain`. Lembre-se da estrutura do dicionário `dic_url_per_domain`. Não esqueça de armazenar que esta URL já foi descoberta. Este método será testado por teste unitário apenas após a implementação da obtenção das URLs. Lembre-se de como trabalhar com [dicionários](https://daniel-hasan.github.io/cefet-web-grad/classes/python2/#mais-colecoes)

# %% [markdown]
# **Atividade 5 método `get_next_url` - obtém a próxima URL da fila**: Este método retona uma tupla `url,profundade` da próxima URL a ser coletada por meio da fila `dic_url_per_domain` retirando este item da fila. Lembre-se que:
#
# - Ele deverá retornar a primeira URL do primeiro servidor que estiver acessível.
# - Você deve indicar que o servidor foi acessado
# - Caso a fila deste servidor esteja vazia, elimine-o do dicionário
# - Caso não encontre a URL, [coloque a Thread para esperar](https://docs.python.org/2/library/time.html#time.sleep) e, logo após, procure novamente
#
# Logo após, você já pode executar o teste unitário para verificar se a obtenção e adição de URLs está correta. Caso haja algum problema, existem já alguns prints comentados no código, descomente-os para verificar se o fluxo está ocorrendo da forma correta. Você deverá entregar sem a exibição desses prints (caso contrário, perderá pontos).

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_add_remove_page
# Out:
# Verificação da ordem das URLs...
# Resgatando a segunda página do mesmo dominio...
# Tempo esperado: 5 segundos
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.016s
#
# OK

# %% [markdown]
# **Atividade 6 método `can_fetch_page`**: Este método deve retornar verdadeiro caso a url (Objeto `ParseResult`), passada como parâmetro, pode ser coletada de acordo com o `Robots.txt` do domínio. Para isso, você deve usar o [`RobotFileParser`](https://docs.python.org/3/library/urllib.robotparser.html) para requisitar a URL do `robots.txt` deste domínio. Por razões de performance, você só poderá requisitar o robots.txt uma única vez por domínio. Assim, use o `dic_robots_per_domain` apropriadamente. Execute o teste unitário abaixo para verificar seu funcionamento.

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_can_fetch
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.052s
#
# OK

# %% [markdown]
# **Atividade 7 - Inicialização das sementes no construtor**: No construtor da classe `Scheduler` você deve adicionar as páginas sementes na fila. Tais sementes são passadas pelo parametro `arr_urls_seeds` do construtor.

# %%
# !python -m crawler.scheduler_test SchedulerTest.test_init
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# Logo após, utize a anotação @synchronized aonde julgar necessário para transformar em ThreadSafe.

# %% [markdown]
# ## PageFetcher

# %% [markdown]
# **Atividade 8 - Efetuar a requisição - método `request_url`:** Neste método você irá fazer a requisição usando a api [requests](https://requests.readthedocs.io/en/master/). Além disso, deve-se informar no cabeçalho (em `User-Agent`) o nome do coletor. O método deverá retornar o conteúdo (em binário) apenas se o conteúdo for HTML (ver no cabeçalho da resposta o tipo do conteúdo). Caso não seja, ele deverá retornar nulo.

# %%
# !python -m crawler.page_fetcher_test PageFetcherTest.test_request_url
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.872s
#
# OK

# %% [markdown]
# **Atividade 9 extração das URLs por meio do método `discover_links`**: A partir do conteúdo (texto em binário) `bin_str_content` deve-se extrair seus os links. O conteúdo esta em binário, pois, o BeautifulSoup, internamente, verifica o encoding por meio da [tag meta](https://www.w3schools.com/tags/att_meta_charset.asp) e converte para UTF8. A URL da página coletada é um objeto ParseResult `obj_url` que está na profundidade `int_depth`.
#
# Para cada URL extraída, você deverá retornar uma tupla com a URL (objeto ParseResult) e a sua profundidade. Utilize o comando `yield` para retornar essas tuplas. A profundidade é calculada de por meio de  `obj_url` e `int_depth`, conforme comentado em sala de aula.
#
# Para a extração dos links, use o [CSS Selector do BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors). Seletor CSS é uma expressão que define quais elementos HTML serão estilizados pelo CSS. No *Beatifulsoup* eles são usados para selecionar quais tags serão extraídas. Veja o exemplo de uso e brinque abaixo. Caso precise, veja aqui um pouco de seletores CSS: [slides de Web](https://fegemo.github.io/cefet-front-end/classes/css2/#outros-seletores), [documentação MDN](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors).

# %%
from bs4 import BeautifulSoup

# %%
# !python -m crawler.page_fetcher_test PageFetcherTest.test_discover_links
# Out:
# Simulação da extração de links da página http://www.pudim.com.br na profundidade nível 2...
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %% [markdown]
# **Atividade 10 - método que solicita uma nova URL**: Por meio do método `crawl_new_url` você deverá utilizar os métodos previamente implementados para:
#
# - Solicitar ao escalonador uma nova URL
# - Fazer a requisição e obter o resultado (em binário)
# - Caso a URL seja um HTML válido, imprima esta URL e extraia os seus links

# %% [markdown]
# **Atividade 12 - método run**: Este método deve coletar páginas enquanto a coleta não foi finalizada

# %% [markdown]
# **Atividade 11 - um pequeno teste para finalizar: ** Use as sementes do seu grupo e crie abaixo um escalonador e 5 PageFetchers para extrair 30 páginas. Imprima também o tempo gasto total.

# %%
from crawler.scheduler import *
from crawler.page_fetcher import *
from urllib.parse import urlparse
from datetime import datetime, timedelta

def start_Escalonador():
    Escalonador = Scheduler(str_usr_agent="Wall-E (https://assisraphael.github.io/PageColector/infoWalleBot)",
                                    int_page_limit=100,
                                    int_depth_limit=6,
                                    arr_urls_seeds=["https://translate.google.com.br/",
                                                    "https://www.invertexto.com/contador-caracteres",
                                                    "https://www.udemy.com/",
                                                    "http://www.google.com.br/",
                                                    "https://www.folha.uol.com.br/"])

    Escalonador.add_new_page(urlparse("https://translate.google.com.br/"), 0)
    Escalonador.add_new_page(urlparse("https://www.invertexto.com/contador-caracteres"), 0)
    Escalonador.add_new_page(urlparse("https://www.udemy.com/"), 0)
    Escalonador.add_new_page(urlparse("http://www.google.com.br/"), 0)
    Escalonador.add_new_page(urlparse("https://www.folha.uol.com.br/"), 0)

    return Escalonador

threads = 10
Escalonador = start_Escalonador()
tempoInicial = datetime.now()
fetchers = [PageFetcher(Escalonador) for i in range(threads)]
print(len(fetchers))
for f in fetchers:
    f.run()
tempoFinal = datetime.now()
print(''*15,'\n')
print('Tempo total:',tempoFinal-tempoInicial,'\n\n')
# Out:
# 10
# https://translate.google.com.br/?hl=pt-BR&tab=TT
# https://www.google.com.br/intl/pt-BR/about/products?tab=Th
# https://myaccount.google.com/?utm_source=OGB&tab=Tk&utm_medium=app
# https://www.google.com.br/webhp?tab=Tw
# https://maps.google.com.br/maps?hl=pt-BR&tab=Tl
# https://www.youtube.com/?gl=BR&tab=T1
# https://play.google.com/?hl=pt-BR&tab=T8
# https://news.google.com/?tab=Tn
# https://mail.google.com/mail/?tab=Tm
# https://meet.google.com/?hs=197
# https://chat.google.com/
# https://contacts.google.com/?hl=pt-BR&tab=TC
# https://drive.google.com/?tab=To
# https://calendar.google.com/calendar?tab=Tc
# https://translate.google.com.br/?hl=pt-BR&tab=TT
# https://photos.google.com/?tab=Tq&pageId=none
# https://duo.google.com/?usp=duo_ald
# https://www.google.com/chrome/?brand=CHZO&utm_source=google.com&utm_medium=desktop-app-launcher&utm_campaign=desktop-app-launcher&utm_content=chrome-logo&utm_keyword=CHZO
# https://www.google.com.br/shopping?hl=pt-BR&source=og&tab=Tf
# https://docs.google.com/document/?usp=docs_alc
# https://docs.google.com/spreadsheets/?usp=sheets_alc
# https://docs.google.com/presentation/?usp=slides_alc
# https://books.google.com.br/?hl=pt-BR&tab=Tp
# https://www.blogger.com/?tab=Tj
# https://hangouts.google.com/
# https://keep.google.com/
# https://jamboard.google.com/?usp=jam_ald
# https://earth.google.com/web/
# https://www.google.com.br/save
# https://artsandculture.google.com/?hl=pt-BR&utm_source=ogs.google.com&utm_medium=referral
# https://ads.google.com/home/?subid=ww-ww-et-g-aw-a-vasquette_ads_cons_1!o2
# https://podcasts.google.com/
# https://www.google.com/travel/?dest_src=al
# https://docs.google.com/forms/?usp=forms_alc
# https://www.google.com.br/intl/pt-BR/about/products?tab=Th
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://translate.google.com.br/&followup=https://translate.google.com.br/&ec=GAZAMw
# https://translate.google.com.br/?hl=pt-BR&tab=TT
# https://translate.google.com/about/?hl=pt-BR
# https://policies.google.com/?hl=pt-BR
# https://support.google.com/translate/?hl=pt-BR
# https://www.google.com/about?hl=pt-BR
# https://support.google.com/translate?p=gendered_translations&hl=pt_BR
# https://translate.google.com.br/history
# https://translate.google.com.br/saved
# https://translate.google.com.br/contribute
# https://translate.google.com.br/?hl=pt-BR&tab=TT
# https://www.google.com.br/intl/pt-BR/about/products?tab=Th
# https://myaccount.google.com/?utm_source=OGB&tab=Tk&utm_medium=app
# https://www.google.com.br/webhp?tab=Tw
# https://maps.google.com.br/maps?hl=pt-BR&tab=Tl
# https://www.youtube.com/?gl=BR&tab=T1
# https://play.google.com/?hl=pt-BR&tab=T8
# https://news.google.com/?tab=Tn
# https://mail.google.com/mail/?tab=Tm
# https://meet.google.com/?hs=197
# https://chat.google.com/
# https://contacts.google.com/?hl=pt-BR&tab=TC
# https://drive.google.com/?tab=To
# https://calendar.google.com/calendar?tab=Tc
# https://translate.google.com.br/?hl=pt-BR&tab=TT
# https://photos.google.com/?tab=Tq&pageId=none
# https://duo.google.com/?usp=duo_ald
# https://www.google.com/chrome/?brand=CHZO&utm_source=google.com&utm_medium=desktop-app-launcher&utm_campaign=desktop-app-launcher&utm_content=chrome-logo&utm_keyword=CHZO
# https://www.google.com.br/shopping?hl=pt-BR&source=og&tab=Tf
# https://docs.google.com/document/?usp=docs_alc
# https://docs.google.com/spreadsheets/?usp=sheets_alc
# https://docs.google.com/presentation/?usp=slides_alc
# https://books.google.com.br/?hl=pt-BR&tab=Tp
# https://www.blogger.com/?tab=Tj
# https://hangouts.google.com/
# https://keep.google.com/
# https://jamboard.google.com/?usp=jam_ald
# https://earth.google.com/web/
# https://www.google.com.br/save
# https://artsandculture.google.com/?hl=pt-BR&utm_source=ogs.google.com&utm_medium=referral
# https://ads.google.com/home/?subid=ww-ww-et-g-aw-a-vasquette_ads_cons_1!o2
# https://podcasts.google.com/
# https://www.google.com/travel/?dest_src=al
# https://docs.google.com/forms/?usp=forms_alc
# https://www.google.com.br/intl/pt-BR/about/products?tab=Th
# https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://translate.google.com.br/?hl%3Dpt-BR%26tab%3DTT&followup=https://translate.google.com.br/?hl%3Dpt-BR%26tab%3DTT&hl=pt-BR&ec=GAZAMw
# https://translate.google.com.br/?hl=pt-BR&tab=TT
# https://translate.google.com/about/?hl=pt-BR
# https://policies.google.com/?hl=pt-BR
# https://support.google.com/translate/?hl=pt-BR
# https://www.google.com/about?hl=pt-BR
# https://support.google.com/translate?p=gendered_translations&hl=pt_BR
# https://translate.google.com.br/history
# https://translate.google.com.br/saved
# https://translate.google.com.br/contribute
# https://accounts.google.com/signin/usernamerecovery?continue=https%3A%2F%2Ftranslate.google.com.br%2Fhistory&hl=pt
# https://accounts.google.com/AccountChooser?continue=https%3A%2F%2Ftranslate.google.com.br%2Fhistory&followup=https%3A%2F%2Ftranslate.google.com.br%2Fhistory
# https://accounts.google.com/SignUp?continue=https%3A%2F%2Ftranslate.google.com.br%2Fhistory
# https://www.google.com/intl/pt/about
# https://accounts.google.com/TOS?loc=BR&hl=pt&privacy=true
# https://accounts.google.com/TOS?loc=BR&hl=pt
# http://www.google.com/support/accounts?hl=pt
# https://www.invertexto.com/
# https://www.instagram.com/invertexto/
# https://www.udemy.com/organization-growth/request-demo/?locale=en_US&next=%2F&ref=ufb_home-body&utm_campaign=mx-hooks&utm_content=ufb-home-body&utm_medium=referral&utm_source=marketplace&utm_term=
# https://www.udemy.com/udemy-business/?locale=en_US&mx_pg=home-page&path=%2F&ref=footer
# https://www.udemy.com/teaching/?ref=teach_footer
# https://www.udemy.com/mobile/
# https://about.udemy.com/?locale=en-us
# https://about.udemy.com/company?locale=en-us#offices
# https://about.udemy.com/careers?locale=en-us
# https://blog.udemy.com/?ref=footer
# https://www.udemy.com/support/
# https://www.udemy.com/affiliate/
# https://www.udemy.com/terms/imprint-contact/
# https://www.udemy.com/terms/
# https://www.udemy.com/terms/privacy/
# javascript:void(0);
# https://www.udemy.com/sitemap/
# https://www.udemy.com/
# http://www.google.com.br/imghp?hl=pt-BR&tab=wi
# http://maps.google.com.br/maps?hl=pt-BR&tab=wl
# https://play.google.com/?hl=pt-BR&tab=w8
# http://www.youtube.com/?gl=BR&tab=w1
# https://news.google.com/?tab=wn
# https://mail.google.com/mail/?tab=wm
# https://drive.google.com/?tab=wo
# https://www.google.com.br/intl/pt-BR/about/products?tab=wh
# http://www.google.com.br/history/optout?hl=pt-BR
# http://www.google.com.br/preferences?hl=pt-BR
# https://accounts.google.com/ServiceLogin?hl=pt-BR&passive=true&continue=http://www.google.com.br/&ec=GAZAAQ
# http://www.google.com.br/advanced_search?hl=pt-BR&authuser=0
# http://www.google.com.br/intl/pt-BR/ads/
# http://www.google.com.br/services/
# http://www.google.com.br/intl/pt-BR/about.html
# http://www.google.com.br/setprefdomain?prefdom=US&sig=K_0Po-G8sUQtlh4Y5YHG0nNPHUumk%3D
# http://www.google.com.br/intl/pt-BR/policies/privacy/
# http://www.google.com.br/intl/pt-BR/policies/terms/
# https://minhafolha.folha.uol.com.br/
# //assinaturas.folha.com.br
# //www.folha.uol.com.br/
# https://www.folha.uol.com.br/#conteudo
# https://www.folha.uol.com.br/#menu
# https://www.folha.uol.com.br/#rodape
# //login.folha.com.br/login
# //login.folha.com.br/login
# //login.folha.com.br/logout
# https://minhafolha.folha.uol.com.br/
# https://minhafolha.folha.uol.com.br/artigos
# https://minhafolha.folha.uol.com.br/newsletters
# //login.folha.com.br/assinante
# //login.folha.com.br/perfil
# //login.folha.com.br/conta
# //atendimento.folha.com.br/
# https://www.folha.uol.com.br/
# //acervo.folha.uol.com.br/digital/index.do
# //minhafolha.folha.uol.com.br
# https://www1.folha.uol.com.br/ultimas-noticias
# https://www1.folha.uol.com.br/opiniao
# https://www1.folha.uol.com.br/poder
# https://www1.folha.uol.com.br/mercado
# https://www1.folha.uol.com.br/mundo
# http://www1.folha.uol.com.br/cotidiano/coronavirus/
# https://www1.folha.uol.com.br/esporte/toquio-2020/
# https://www1.folha.uol.com.br/ilustrada
# https://f5.folha.uol.com.br
# //www1.folha.uol.com.br/internacional/en/
# //www1.folha.uol.com.br/internacional/es/
# https://assinaturas.folha.com.br/410520
# https://assinaturas.folha.com.br/410520
# //www.folha.uol.com.br/
# //assinaturas.folha.com.br
# https://minhafolha.folha.uol.com.br/
# https://minhafolha.folha.uol.com.br/artigos
# https://minhafolha.folha.uol.com.br/newsletters
# //login.folha.com.br/assinante
# //login.folha.com.br/perfil
# //login.folha.com.br/conta
# //atendimento.folha.com.br/
# https://www.folha.uol.com.br/
# //acervo.folha.uol.com.br/digital/index.do
# //www1.folha.uol.com.br/ultimas-noticias/
# //www1.folha.uol.com.br/fsp/
# https://www1.folha.uol.com.br/opiniao
# https://www.folha.uol.com.br/#sidebarmenu-opiniao
# https://www1.folha.uol.com.br/opiniao/editoriais/
# https://fotografia.folha.uol.com.br/charges
# https://www1.folha.uol.com.br/opiniao/tendenciasdebates/
# https://www1.folha.uol.com.br/colunaseblogs
# https://www.folha.uol.com.br/#sidebarmenu-colunas-e-blogs
# https://www1.folha.uol.com.br/colunaseblogs/#so-colunas
# https://www1.folha.uol.com.br/colunaseblogs/#so-blogs
# https://www1.folha.uol.com.br/rotativas/
# https://www1.folha.uol.com.br/maispopulares
# https://www.folha.uol.com.br/#sidebarmenu-mais-populares
# https://www1.folha.uol.com.br/maispopulares/#mais-lidas
# https://www1.folha.uol.com.br/maispopulares/#mais-enviadas
# https://www1.folha.uol.com.br/maispopulares/#mais-comentadas
# https://www.agora.uol.com.br/
# https://acervo.folha.uol.com.br/
# https://www.folha.uol.com.br/#sidebarmenu-acervo-folha
# https://www1.folha.uol.com.br/especial/2017/ha-50-anos
# https://www1.folha.uol.com.br/especial/2017/saiu-no-np
# https://fotografia.folha.uol.com.br/
# https://www1.folha.uol.com.br/folha-100-anos/
# https://www1.folha.uol.com.br/cotidiano/coronavirus/
# https://www1.folha.uol.com.br/poder/
# https://www.folha.uol.com.br/#sidebarmenu-poder
# https://www1.folha.uol.com.br/especial/2018/governo-bolsonaro/
# https://www1.folha.uol.com.br/poder/eleicoes/2022/
# https://www1.folha.uol.com.br/colunas/painel/
# https://www1.folha.uol.com.br/especial/2017/entrevista-da-segunda/
# https://www1.folha.uol.com.br/especial/2014/petrolao/
# https://www1.folha.uol.com.br/deltafolha/
# https://www1.folha.uol.com.br/especial/2018/governo-bolsonaro/
# https://www.folha.uol.com.br/#sidebarmenu-governo-bolsonaro
# https://www1.folha.uol.com.br/especial/2018/folha-informacoes/
# https://www1.folha.uol.com.br/colunas/painel/
# https://www1.folha.uol.com.br/mercado
# https://www.folha.uol.com.br/#sidebarmenu-mercado
# https://www1.folha.uol.com.br/mercado/previdencia/
# https://www1.folha.uol.com.br/mercado/agrofolha/
# https://www1.folha.uol.com.br/colunas/painelsa/
# https://www1.folha.uol.com.br/mercado/folhainvest/
# https://www1.folha.uol.com.br/mercado/cifraseletras/
# https://www1.folha.uol.com.br/mercado/startup/
#  https://www1.folha.uol.com.br/mpme/
# http://publicidadelegal.folha.uol.com.br/
# https://www1.folha.uol.com.br/mercado/recall/
# https://www1.folha.uol.com.br/cotidiano
# https://www.folha.uol.com.br/#sidebarmenu-cotidiano
# https://www1.folha.uol.com.br/educacao
# https://www1.folha.uol.com.br/cotidiano/riodejaneiro/
# https://www1.folha.uol.com.br/loterias/
# http://tempo.folha.uol.com.br/
# https://www1.folha.uol.com.br/dias-melhores
# https://www1.folha.uol.com.br/mundo
# https://www.folha.uol.com.br/#sidebarmenu-mundo
# https://www1.folha.uol.com.br/especial/2017/coreia-do-norte/
# https://www1.folha.uol.com.br/mundo/china/2020/
# https://www1.folha.uol.com.br/mundo/governo-biden/
# https://www1.folha.uol.com.br/especial/2018/venezuela/
# https://www1.folha.uol.com.br/especial/2018/portugal/
# https://www1.folha.uol.com.br/equilibrioesaude
# https://www.folha.uol.com.br/#sidebarmenu-saude
# https://www1.folha.uol.com.br/equilibrioesaude/saude-responde/
# https://www1.folha.uol.com.br/equilibrioesaude/cannabis-medicinal/2019/
# https://www1.folha.uol.com.br/ciencia
# https://www.folha.uol.com.br/#sidebarmenu-ciencia
# https://www1.folha.uol.com.br/ambiente
# https://www1.folha.uol.com.br/esporte/
# https://www.folha.uol.com.br/#sidebarmenu-esporte
# https://www1.folha.uol.com.br/esporte/campeonato-brasileiro/2021
# https://www1.folha.uol.com.br/esporte/futebolinternacional/
# https://www1.folha.uol.com.br/ilustrada
# https://www.folha.uol.com.br/#sidebarmenu-ilustrada
# https://www1.folha.uol.com.br/colunas/monicabergamo/
# http://www1.folha.uol.com.br/ilustrada/cartum/cartunsdiarios
# https://www1.folha.uol.com.br/colunas/walter-porto/
# https://www1.folha.uol.com.br/ilustrada/escuta-aqui/
# https://www1.folha.uol.com.br/ilustrada/e-coisa-fina/
# https://www1.folha.uol.com.br/comida/
# https://www1.folha.uol.com.br/ilustrissima
# https://f5.folha.uol.com.br
# https://www.folha.uol.com.br/#sidebarmenu-f5
# https://f5.folha.uol.com.br/bichos
# https://f5.folha.uol.com.br/celebridades
# https://f5.folha.uol.com.br/horoscopo/
# https://f5.folha.uol.com.br/voceviu
# https://f5.folha.uol.com.br/televisao/
# https://guia.folha.uol.com.br
# https://www1.folha.uol.com.br/turismo
# https://www1.folha.uol.com.br/folhinha
# https://www1.folha.uol.com.br/especial/2021/
# https://www1.folha.uol.com.br/folha-topicos/folha-explica/
# https://www1.folha.uol.com.br/webstories/
# https://www1.folha.uol.com.br/dias-melhores/
# https://seminariosfolha.folha.com.br/
# https://www1.folha.uol.com.br/empreendedorsocial/
# https://saopaulo.folha.uol.com.br/o-melhor-de-saopaulo/
# https://www1.folha.uol.com.br/tv
# https://www.folha.uol.com.br/
# https://www.folha.uol.com.br/#sidebarmenu-parceiros
# https://www1.folha.uol.com.br/mercado/aeroin
# https://www1.folha.uol.com.br/especial/2018/agencia-fapesp/
# https://www1.folha.uol.com.br/bbc/
# https://www1.folha.uol.com.br/caixin/
# https://www1.folha.uol.com.br/dw/
# https://www1.folha.uol.com.br/mundo/financialtimes/
# https://www1.folha.uol.com.br/especial/2018/globalmedia/
# https://www1.folha.uol.com.br/mundo/latinoamerica21/
# http://piaui.folha.uol.com.br/
# https://www1.folha.uol.com.br/publico
# https://quatrocincoum.folha.uol.com.br/
# https://www1.folha.uol.com.br/rfi/
# https://www1.folha.uol.com.br/mundo/nyt/
# http://telepadi.folha.uol.com.br/
# http://origemsurf.folha.uol.com.br/
# https://www1.folha.uol.com.br/banco-de-dados
# https://www1.folha.uol.com.br/paineldoleitor
# https://www1.folha.uol.com.br/sobretudo
# https://www.folha.uol.com.br/#sidebarmenu-sobre-tudo
# https://www1.folha.uol.com.br/sobretudo/carreiras
# https://www1.folha.uol.com.br/sobretudo/morar
# https://www1.folha.uol.com.br/sobretudo/rodas
# https://www.folha.uol.com.br/
# https://www.folha.uol.com.br/#sidebarmenu-mais-secoes
# https://www1.folha.uol.com.br/internacional/es/
# https://www1.folha.uol.com.br/internacional/en/
# https://www1.folha.uol.com.br/mapas/
# http://folhaleaks.folha.com.br/
# https://www1.folha.uol.com.br/tudosobre/
# https://www1.folha.uol.com.br/folha-topicos/
# http://transparencia.folha.uol.com.br
# https://www1.folha.uol.com.br/fsp
# https://www1.folha.uol.com.br/mapa-do-site/
# http://classificados1.folha.uol.com.br/
# https://www1.folha.uol.com.br/falecomafolha
# https://www.folha.uol.com.br/#sidebarmenu-fale-com-a-folha
# https://www1.folha.uol.com.br/falecomafolha
# http://www.publicidade.folha.com.br
# http://atendimento.folha.com.br
# https://www1.folha.uol.com.br/erramos
# https://www1.folha.uol.com.br/ombudsman
# https://www1.folha.uol.com.br/paineldoleitor
# https://www1.folha.uol.com.br/institucional/
# https://www.folha.uol.com.br/#sidebarmenu-sobre-a-folha
# http://www1.folha.uol.com.br/institucional
# https://www1.folha.uol.com.br/institucional/expediente.shtml
# http://www1.folha.uol.com.br/paineldoleitor/politicadeprivacidade/
# https://temas.folha.uol.com.br/projeto-editorial-da-folha/projeto-editorial-2017/
# https://www1.folha.uol.com.br/treinamento/
# http://www1.folha.uol.com.br/folha/trabalhe/vagas.html
# //www1.folha.uol.com.br/internacional/en/
# //www1.folha.uol.com.br/internacional/es/
# //twitter.com/folha
# //www.linkedin.com/company/folha-de-spaulo/
# //www.instagram.com/folhadespaulo/
# //www1.folha.uol.com.br/feed
# https://www1.folha.uol.com.br/especial/2018/governo-bolsonaro
# https://secure.folha.com.br/folha?gid=FOL
# https://www.folha.uol.com.br/
# https://www1.folha.uol.com.br/poder/2021/07/prevaricacao-se-aplica-a-servidor-publico-nao-a-mim-diz-bolsonaro-sobre-caso-covaxin.shtml
# https://www1.folha.uol.com.br/poder/2021/07/procuradoria-abre-apuracao-sobre-denuncia-de-propina-em-compra-de-vacinas-no-governo-bolsonaro.shtml
# https://www1.folha.uol.com.br/poder/2021/07/presidente-da-cpi-afirma-que-crime-de-responsabilidade-de-bolsonaro-esta-cada-vez-mais-claro.shtml
# https://www1.folha.uol.com.br/poder/2021/07/apos-falas-golpistas-de-bolsonaro-fux-se-reune-com-presidente-e-preve-reuniao-de-conciliacao-entre-os-poderes.shtml
# https://www1.folha.uol.com.br/equilibrioesaude/2021/07/casal-e-impedido-de-se-vacinar-com-camisa-contra-bolsonaro-no-rio.shtml
# https://fotografia.folha.uol.com.br/galerias/1705073188936704-protestos-na-africa-do-sul-girassol-gigante-e-fenomeno-climatico-veja-as-fotos-de-hoje
# https://www1.folha.uol.com.br/ambiente/2021/07/incendios-em-ms-queimam-ao-menos-3750-hectares-em-bonito-e-jardim.shtml
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x0000026A31909208>: Failed to establish a new connection: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='about.google', port=443): Max retries exceeded with url: /intl/pt-BR/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000026A31909208>: Failed to establish a new connection: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu\r\ncorretamente após um período de tempo ou a conexão estabelecida falhou\r\nporque o host conectado não respondeu',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-1-5bdd4a35629c> in <module>()
#      28 print(len(fetchers))
#      29 for f in fetchers:
# ---> 30     f.run()
#      31 tempoFinal = datetime.now()
#      32 print(''*15,'\n')
#
# ~\Documents\GitHub\PageColector\crawler\page_fetcher.py in run(self)
#      79         """
#      80         while not self.obj_scheduler.has_finished_crawl():
# ---> 81             self.crawl_new_url()
#
# ~\Documents\GitHub\PageColector\crawler\page_fetcher.py in crawl_new_url(self)
#      59         """
#      60         obj_url, int_depth = self.obj_scheduler.get_next_url()
# ---> 61         bin_str_content = self.request_url(obj_url)
#      62
#      63         if bin_str_content is not None:
#
# ~\Documents\GitHub\PageColector\crawler\page_fetcher.py in request_url(self, obj_url)
#      22         if "http" not in url:
#      23             url = "http:" + url
# ---> 24         response = requests.get(url)
#      25         response.headers['User-Agent'] = self.obj_scheduler.str_usr_agent
#      26         if response.headers['content-type'].find('text/html') == -1:
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='about.google', port=443): Max retries exceeded with url: /intl/pt-BR/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x0000026A31909208>: Failed to establish a new connection: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu\r\ncorretamente após um período de tempo ou a conexão estabelecida falhou\r\nporque o host conectado não respondeu',))

# %% [markdown]
# # Bibliografia
#
# Baeza-Yates, Ricardo; Ribeiro-Neto, Berthier. **Modern information retrieval: the concepts and technology behind search**. ACM Press, 2011.
#
# Batista, Natércia ; Brandão, Michele ; Pinheiro, Michele ; Dalip, Daniel ; Moro, Mirella . **[Dados de Múltiplas Fontes da Web: coleta, integração e pré-processamento](https://sol.sbc.org.br/livros/index.php/sbc/catalog/download/8/19/58-1?inline=1)**. Minicursos do XXIV Simpósio Brasileiro de Sistemas Multimídia e Web. 1ed.: Sociedade Brasileira de Computação, 2018, v. , p. 153-192.
